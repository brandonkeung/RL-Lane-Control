# %%
import torch
print(torch.cuda.is_available())
print(torch.cuda.get_device_name(0) if torch.cuda.is_available() else "No CUDA device")
# Out:
# True
# NVIDIA GeForce RTX 4060 Laptop GPU

# %%
import torch
import torch.nn as nn
from torch.distributions import Categorical

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")

class RolloutBuffer:
    def __init__(self):
        self.actions = []
        self.states = []
        self.logprobs = []
        self.rewards = []
        self.state_values = []
        self.is_terminals = []

    def clear(self):
        self.actions.clear()
        self.states.clear()
        self.logprobs.clear()
        self.rewards.clear()
        self.state_values.clear()
        self.is_terminals.clear()

class ActorCritic(nn.Module):
    def __init__(self, state_dim, action_dim):
        super(ActorCritic, self).__init__()

        self.actor = nn.Sequential(
            nn.Linear(state_dim, 64),
            nn.Tanh(),
            nn.Linear(64, 64),
            nn.Tanh(),
            nn.Linear(64, action_dim),
            nn.Softmax(dim=-1)
        )

        self.critic = nn.Sequential(
            nn.Linear(state_dim, 64),
            nn.Tanh(),
            nn.Linear(64, 64),
            nn.Tanh(),
            nn.Linear(64, 1)
        )

    def act(self, state, deterministic=False):
        action_probs = self.actor(state)
        if deterministic:
            action = torch.argmax(action_probs, dim=-1)
            action_logprob = torch.log(action_probs.gather(1, action.unsqueeze(-1)).squeeze(-1))
        else:
            dist = Categorical(action_probs)
            action = dist.sample()
            action_logprob = dist.log_prob(action)
        state_value = self.critic(state)
        return action, action_logprob, state_value

    def evaluate(self, states, actions):
        action_probs = self.actor(states)
        dist = Categorical(action_probs)
        action_logprobs = dist.log_prob(actions)
        dist_entropy = dist.entropy()
        state_values = self.critic(states).squeeze(-1)
        return action_logprobs, state_values, dist_entropy

class PPO:
    def __init__(self, state_dim, action_dim, lr_actor, lr_critic, gamma, K_epochs, eps_clip):
        self.gamma = gamma
        self.eps_clip = eps_clip
        self.K_epochs = K_epochs

        self.buffer = RolloutBuffer()

        self.policy = ActorCritic(state_dim, action_dim).to(device)
        self.optimizer = torch.optim.Adam([
            {'params': self.policy.actor.parameters(), 'lr': lr_actor},
            {'params': self.policy.critic.parameters(), 'lr': lr_critic}
        ])

        self.policy_old = ActorCritic(state_dim, action_dim).to(device)
        self.policy_old.load_state_dict(self.policy.state_dict())
        self.MseLoss = nn.MSELoss()

    def select_action(self, state):
        state = torch.FloatTensor(state).flatten().unsqueeze(0).to(device)
        with torch.no_grad():
            action, action_logprob, state_value = self.policy_old.act(state, deterministic=False)

        self.buffer.states.append(state.squeeze(0))
        self.buffer.actions.append(action)
        self.buffer.logprobs.append(action_logprob)
        self.buffer.state_values.append(state_value.squeeze())

        return action.item()

    def update(self, mini_batch_size=256):
        # Compute discounted rewards-to-go
        rewards = []
        discounted_reward = 0
        for reward, is_terminal in zip(reversed(self.buffer.rewards), reversed(self.buffer.is_terminals)):
            discounted_reward = reward + (self.gamma * discounted_reward * (1 - is_terminal))
            rewards.insert(0, discounted_reward)
        rewards = torch.tensor(rewards, dtype=torch.float32).to(device)
        # rewards = (rewards - rewards.mean()) / (rewards.std() + 1e-7)

        # Convert rollout buffer to tensors
        old_states = torch.stack(self.buffer.states).to(device)
        old_actions = torch.stack(self.buffer.actions).to(device)
        old_logprobs = torch.stack(self.buffer.logprobs).to(device)
        old_state_values = torch.stack(self.buffer.state_values).to(device)
        advantages = rewards - old_state_values.detach()
        # advantages = (advantages - advantages.mean()) / (advantages.std() + 1e-8)

        # Total data size
        dataset_size = old_states.size(0)
        for _ in range(self.K_epochs):
            # Shuffle indices
            indices = torch.randperm(dataset_size)
            for start in range(0, dataset_size, mini_batch_size):
                end = start + mini_batch_size
                mb_idx = indices[start:end]

                mb_states = old_states[mb_idx]
                mb_actions = old_actions[mb_idx]
                mb_logprobs = old_logprobs[mb_idx]
                mb_advantages = advantages[mb_idx]
                mb_returns = rewards[mb_idx]

                # Evaluate with current policy
                logprobs, state_values, dist_entropy = self.policy.evaluate(mb_states, mb_actions)
                ratios = torch.exp(logprobs - mb_logprobs.detach())

                # Clipped objective
                surr1 = ratios * mb_advantages
                surr2 = torch.clamp(ratios, 1 - self.eps_clip, 1 + self.eps_clip) * mb_advantages
                loss = -torch.min(surr1, surr2) \
                    + 0.5 * self.MseLoss(state_values, mb_returns) \
                    - 0.01 * dist_entropy

                self.optimizer.zero_grad()
                loss.mean().backward()
                self.optimizer.step()

        self.policy_old.load_state_dict(self.policy.state_dict())
        self.buffer.clear()

        
    def select_action_eval(self, state):
        state = torch.FloatTensor(state).flatten().unsqueeze(0).to(device)
        with torch.no_grad():
            action, _, _ = self.policy_old.act(state, deterministic=True)
        return action.item()
# Out:
# Using device: cuda

# %%
import gymnasium as gym
import highway_env
import numpy as np
import matplotlib.pyplot as plt

BASE_CONFIG = {
    "observation":       {"type": "Kinematics"},
    "action":            {"type": "DiscreteMetaAction"},
    "lanes_count":       4,
    "controlled_vehicles": 1,
    "duration":          40,
    "ego_spacing":       2,
    "vehicles_density":  1,
    "collision_reward":  -1,
    "right_lane_reward": 0.1,
    "high_speed_reward": 0.4,
    "lane_change_reward": 0,
    "normalize_reward":  True,
    "offroad_terminal":  False,
}

# %%
SCENARIOS = {
    "Slow":   {"reward_speed_range": [10, 20]},
    "Normal": {"reward_speed_range": [20, 30]},
    "Fast":   {"reward_speed_range": [30, 40]},
}

def train(cfg, label=""):
    env = gym.make("highway-v0", render_mode="rgb_array").unwrapped
    env.configure(cfg)
    print(f"\nTraining scenario: {label}")
    print(env.observation_space)
    
    state_dim = np.prod(env.observation_space.shape)
    action_dim = env.action_space.n

    # PPO hyperparameters
    max_episodes = 1500
    max_ep_len = 1000
    update_timestep = 2000
    K_epochs = 10
    eps_clip = 0.2
    gamma = 0.99
    lr_actor = 0.0003
    lr_critic = 0.0003

    episode_reward_history = []
    running_rewards = []
    last_n_reward = 50

    ppo_agent = PPO(state_dim, action_dim, lr_actor, lr_critic, gamma, K_epochs, eps_clip)

    time_step = 0
    i_episode = 0

    while i_episode < max_episodes:
        obs, _ = env.reset()
        current_ep_reward = 0

        for _ in range(max_ep_len):
            action = ppo_agent.select_action(obs)
            next_obs, reward, done, truncated, info = env.step(action)

            ppo_agent.buffer.rewards.append(reward)
            ppo_agent.buffer.is_terminals.append(done or truncated)

            time_step += 1
            current_ep_reward += reward

            if time_step % update_timestep == 0:
                print("update with length "+ str(len(ppo_agent.buffer.rewards)))
                ppo_agent.update()

            obs = next_obs

            if done or truncated:
                break

        i_episode += 1
        episode_reward_history.append(current_ep_reward)

        running_reward = (
            np.mean(episode_reward_history[-last_n_reward:])
            if len(episode_reward_history) > last_n_reward
            else np.mean(episode_reward_history)
        )
        running_rewards.append(running_reward)
        if i_episode % 10 == 0:
            print(f"Episode {i_episode}, Reward: {current_ep_reward:.2f}, Running Avg ({last_n_reward}): {running_reward:.2f}")

    plt.figure(figsize=(10, 5))
    plt.plot(episode_reward_history, label="Episode Reward")
    plt.plot(running_rewards, label=f"Running Avg (last {last_n_reward})", linewidth=2)
    plt.xlabel("Episode")
    plt.ylabel("Reward")
    plt.title(f"PPO Training Rewards - {label}")
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()

    env.close()
    return ppo_agent

if __name__ == "__main__":
    trained_agents = {}
    for label, scenario_cfg in SCENARIOS.items():
        cfg = BASE_CONFIG.copy()
        cfg.update(scenario_cfg)
        agent = train(cfg, label)
        torch.cuda.empty_cache()
        trained_agents[label] = agent
# Out:
# Training scenario: Slow
# Box(-inf, inf, (5, 5), float32)
# Episode 10, Reward: 15.70, Running Avg (50): 9.88
# Episode 20, Reward: 17.82, Running Avg (50): 12.56
# Episode 30, Reward: 12.68, Running Avg (50): 13.07
# Episode 40, Reward: 11.60, Running Avg (50): 13.01
# Episode 50, Reward: 8.03, Running Avg (50): 14.06
# Episode 60, Reward: 34.60, Running Avg (50): 14.60
# Episode 70, Reward: 28.71, Running Avg (50): 15.21
# Episode 80, Reward: 4.00, Running Avg (50): 15.80
# Episode 90, Reward: 11.52, Running Avg (50): 15.80
# Episode 100, Reward: 21.69, Running Avg (50): 14.89
# Episode 110, Reward: 7.65, Running Avg (50): 14.62
# Episode 120, Reward: 4.00, Running Avg (50): 13.45
# update with length 2000
# Episode 130, Reward: 36.08, Running Avg (50): 13.84
# Episode 140, Reward: 7.91, Running Avg (50): 14.75
# Episode 150, Reward: 3.99, Running Avg (50): 15.75
# Episode 160, Reward: 13.69, Running Avg (50): 16.07
# Episode 170, Reward: 2.16, Running Avg (50): 16.66
# Episode 180, Reward: 24.41, Running Avg (50): 17.33
# Episode 190, Reward: 39.72, Running Avg (50): 19.54
# Episode 200, Reward: 17.98, Running Avg (50): 18.93
# Episode 210, Reward: 16.87, Running Avg (50): 20.16
# Episode 220, Reward: 9.74, Running Avg (50): 22.27
# update with length 2000
# Episode 230, Reward: 6.95, Running Avg (50): 21.92
# Episode 240, Reward: 16.24, Running Avg (50): 20.88
# Episode 250, Reward: 9.06, Running Avg (50): 21.59
# Episode 260, Reward: 39.88, Running Avg (50): 23.10
# Episode 270, Reward: 18.75, Running Avg (50): 23.94
# Episode 280, Reward: 1.33, Running Avg (50): 22.69
# Episode 290, Reward: 38.75, Running Avg (50): 22.46
# Episode 300, Reward: 2.11, Running Avg (50): 22.79
# Episode 310, Reward: 6.64, Running Avg (50): 21.64
# update with length 2000
# Episode 320, Reward: 6.97, Running Avg (50): 20.64
# Episode 330, Reward: 39.03, Running Avg (50): 22.19
# Episode 340, Reward: 6.06, Running Avg (50): 23.32
# Episode 350, Reward: 39.13, Running Avg (50): 24.50
# Episode 360, Reward: 18.58, Running Avg (50): 25.64
# Episode 370, Reward: 23.28, Running Avg (50): 23.65
# Episode 380, Reward: 28.94, Running Avg (50): 24.05
# Episode 390, Reward: 1.27, Running Avg (50): 23.22
# update with length 2000
# Episode 400, Reward: 14.93, Running Avg (50): 22.56
# Episode 410, Reward: 39.35, Running Avg (50): 22.62
# Episode 420, Reward: 3.08, Running Avg (50): 23.12
# Episode 430, Reward: 5.82, Running Avg (50): 23.88
# Episode 440, Reward: 17.91, Running Avg (50): 23.66
# Episode 450, Reward: 39.71, Running Avg (50): 23.29
# Episode 460, Reward: 5.25, Running Avg (50): 22.16
# Episode 470, Reward: 10.46, Running Avg (50): 23.19
# update with length 2000
# Episode 480, Reward: 39.61, Running Avg (50): 21.85
# Episode 490, Reward: 9.13, Running Avg (50): 20.79
# Episode 500, Reward: 35.99, Running Avg (50): 20.60
# Episode 510, Reward: 4.12, Running Avg (50): 21.25
# Episode 520, Reward: 3.07, Running Avg (50): 20.48
# Episode 530, Reward: 3.10, Running Avg (50): 19.17
# Episode 540, Reward: 30.97, Running Avg (50): 20.24
# Episode 550, Reward: 4.80, Running Avg (50): 21.50
# Episode 560, Reward: 9.92, Running Avg (50): 20.93
# update with length 2000
# Episode 570, Reward: 39.56, Running Avg (50): 22.20
# Episode 580, Reward: 5.60, Running Avg (50): 23.53
# Episode 590, Reward: 39.46, Running Avg (50): 23.68
# Episode 600, Reward: 5.80, Running Avg (50): 22.66
# Episode 610, Reward: 10.40, Running Avg (50): 23.39
# Episode 620, Reward: 3.18, Running Avg (50): 23.51
# Episode 630, Reward: 2.20, Running Avg (50): 21.16
# Episode 640, Reward: 7.73, Running Avg (50): 20.61
# Episode 650, Reward: 39.63, Running Avg (50): 20.99
# update with length 2000
# Episode 660, Reward: 12.84, Running Avg (50): 20.35
# Episode 670, Reward: 39.86, Running Avg (50): 19.00
# Episode 680, Reward: 39.21, Running Avg (50): 22.35
# Episode 690, Reward: 39.54, Running Avg (50): 24.02
# Episode 700, Reward: 8.31, Running Avg (50): 23.11
# Episode 710, Reward: 21.81, Running Avg (50): 22.86
# Episode 720, Reward: 39.44, Running Avg (50): 26.19
# Episode 730, Reward: 39.91, Running Avg (50): 26.48
# update with length 2000
# Episode 740, Reward: 3.09, Running Avg (50): 25.56
# Episode 750, Reward: 2.24, Running Avg (50): 28.46
# Episode 760, Reward: 39.78, Running Avg (50): 30.33
# Episode 770, Reward: 39.80, Running Avg (50): 28.66
# Episode 780, Reward: 39.57, Running Avg (50): 28.18
# Episode 790, Reward: 5.11, Running Avg (50): 24.85
# Episode 800, Reward: 2.20, Running Avg (50): 21.78
# Episode 810, Reward: 31.20, Running Avg (50): 21.81
# update with length 2000
# Episode 820, Reward: 38.85, Running Avg (50): 19.87
# Episode 830, Reward: 6.96, Running Avg (50): 18.68
# Episode 840, Reward: 24.93, Running Avg (50): 21.62
# Episode 850, Reward: 2.02, Running Avg (50): 22.69
# Episode 860, Reward: 17.98, Running Avg (50): 21.57
# Episode 870, Reward: 5.13, Running Avg (50): 20.49
# Episode 880, Reward: 39.45, Running Avg (50): 20.90
# Episode 890, Reward: 25.88, Running Avg (50): 20.92
# Episode 900, Reward: 39.22, Running Avg (50): 21.54
# update with length 2000
# Episode 910, Reward: 17.11, Running Avg (50): 20.28
# Episode 920, Reward: 19.17, Running Avg (50): 22.37
# Episode 930, Reward: 6.13, Running Avg (50): 21.43
# Episode 940, Reward: 2.11, Running Avg (50): 21.87
# Episode 950, Reward: 8.18, Running Avg (50): 19.66
# Episode 960, Reward: 30.86, Running Avg (50): 20.35
# Episode 970, Reward: 39.59, Running Avg (50): 21.81
# Episode 980, Reward: 38.50, Running Avg (50): 24.60
# update with length 2000
# Episode 990, Reward: 3.00, Running Avg (50): 24.44
# Episode 1000, Reward: 11.11, Running Avg (50): 25.68
# Episode 1010, Reward: 39.50, Running Avg (50): 27.37
# Episode 1020, Reward: 10.18, Running Avg (50): 26.15
# Episode 1030, Reward: 5.92, Running Avg (50): 23.28
# Episode 1040, Reward: 13.01, Running Avg (50): 22.48
# Episode 1050, Reward: 1.96, Running Avg (50): 20.59
# Episode 1060, Reward: 39.52, Running Avg (50): 19.47
# Episode 1070, Reward: 22.56, Running Avg (50): 19.38
# update with length 2000
# Episode 1080, Reward: 39.79, Running Avg (50): 22.03
# Episode 1090, Reward: 39.21, Running Avg (50): 22.95
# Episode 1100, Reward: 17.08, Running Avg (50): 23.97
# Episode 1110, Reward: 19.13, Running Avg (50): 25.02
# Episode 1120, Reward: 11.07, Running Avg (50): 23.66
# Episode 1130, Reward: 39.30, Running Avg (50): 24.11
# Episode 1140, Reward: 39.88, Running Avg (50): 26.00
# update with length 2000
# Episode 1150, Reward: 13.06, Running Avg (50): 27.44
# Episode 1160, Reward: 39.43, Running Avg (50): 27.36
# Episode 1170, Reward: 21.89, Running Avg (50): 28.23
# Episode 1180, Reward: 3.09, Running Avg (50): 26.94
# Episode 1190, Reward: 6.27, Running Avg (50): 23.53
# Episode 1200, Reward: 39.11, Running Avg (50): 24.93
# Episode 1210, Reward: 39.65, Running Avg (50): 25.27
# Episode 1220, Reward: 39.63, Running Avg (50): 24.25
# update with length 2000
# Episode 1230, Reward: 2.11, Running Avg (50): 24.11
# Episode 1240, Reward: 8.00, Running Avg (50): 26.01
# Episode 1250, Reward: 39.66, Running Avg (50): 25.20
# Episode 1260, Reward: 10.89, Running Avg (50): 24.44
# Episode 1270, Reward: 5.14, Running Avg (50): 25.57
# Episode 1280, Reward: 16.92, Running Avg (50): 25.45
# Episode 1290, Reward: 39.86, Running Avg (50): 24.81
# Episode 1300, Reward: 27.86, Running Avg (50): 23.16
# update with length 2000
# Episode 1310, Reward: 2.95, Running Avg (50): 23.65
# Episode 1320, Reward: 5.07, Running Avg (50): 23.50
# Episode 1330, Reward: 6.59, Running Avg (50): 23.19
# Episode 1340, Reward: 2.82, Running Avg (50): 22.98
# Episode 1350, Reward: 12.31, Running Avg (50): 23.31
# Episode 1360, Reward: 2.25, Running Avg (50): 21.70
# Episode 1370, Reward: 39.54, Running Avg (50): 23.86
# Episode 1380, Reward: 39.65, Running Avg (50): 24.45
# update with length 2000
# Episode 1390, Reward: 39.34, Running Avg (50): 26.25
# Episode 1400, Reward: 4.92, Running Avg (50): 25.99
# Episode 1410, Reward: 39.84, Running Avg (50): 23.96
# Episode 1420, Reward: 7.16, Running Avg (50): 21.57
# Episode 1430, Reward: 5.05, Running Avg (50): 20.28
# Episode 1440, Reward: 36.03, Running Avg (50): 19.49
# Episode 1450, Reward: 38.78, Running Avg (50): 20.46
# Episode 1460, Reward: 39.57, Running Avg (50): 23.05
# Episode 1470, Reward: 12.33, Running Avg (50): 22.52
# update with length 2000
# Episode 1480, Reward: 39.43, Running Avg (50): 23.13
# Episode 1490, Reward: 4.02, Running Avg (50): 21.45
# Episode 1500, Reward: 2.99, Running Avg (50): 19.38
# Training scenario: Normal
# Box(-inf, inf, (5, 5), float32)
# Episode 10, Reward: 6.11, Running Avg (50): 9.57
# Episode 20, Reward: 10.72, Running Avg (50): 9.81
# Episode 30, Reward: 23.61, Running Avg (50): 9.29
# Episode 40, Reward: 20.59, Running Avg (50): 10.13
# Episode 50, Reward: 2.27, Running Avg (50): 11.53
# Episode 60, Reward: 2.90, Running Avg (50): 10.88
# Episode 70, Reward: 2.69, Running Avg (50): 11.00
# Episode 80, Reward: 24.08, Running Avg (50): 11.60
# Episode 90, Reward: 9.84, Running Avg (50): 11.97
# Episode 100, Reward: 20.07, Running Avg (50): 11.10
# Episode 110, Reward: 10.42, Running Avg (50): 12.98
# Episode 120, Reward: 22.15, Running Avg (50): 13.61
# update with length 2000
# Episode 130, Reward: 1.98, Running Avg (50): 14.46
# Episode 140, Reward: 3.72, Running Avg (50): 14.32
# Episode 150, Reward: 6.80, Running Avg (50): 14.02
# Episode 160, Reward: 8.07, Running Avg (50): 13.56
# Episode 170, Reward: 18.86, Running Avg (50): 13.17
# Episode 180, Reward: 9.91, Running Avg (50): 13.03
# Episode 190, Reward: 2.88, Running Avg (50): 13.15
# Episode 200, Reward: 15.36, Running Avg (50): 13.51
# Episode 210, Reward: 10.06, Running Avg (50): 13.52
# Episode 220, Reward: 19.78, Running Avg (50): 13.10
# Episode 230, Reward: 3.75, Running Avg (50): 11.71
# Episode 240, Reward: 2.64, Running Avg (50): 10.82
# Episode 250, Reward: 18.79, Running Avg (50): 10.87
# update with length 2000
# Episode 260, Reward: 7.07, Running Avg (50): 9.94
# Episode 270, Reward: 7.28, Running Avg (50): 11.31
# Episode 280, Reward: 2.91, Running Avg (50): 12.10
# Episode 290, Reward: 4.08, Running Avg (50): 11.82
# Episode 300, Reward: 10.74, Running Avg (50): 11.90
# Episode 310, Reward: 10.47, Running Avg (50): 12.31
# Episode 320, Reward: 2.42, Running Avg (50): 10.91
# Episode 330, Reward: 12.77, Running Avg (50): 10.15
# Episode 340, Reward: 12.79, Running Avg (50): 11.80
# Episode 350, Reward: 9.02, Running Avg (50): 10.26
# Episode 360, Reward: 10.58, Running Avg (50): 9.82
# Episode 370, Reward: 1.31, Running Avg (50): 10.41
# Episode 380, Reward: 4.77, Running Avg (50): 10.02
# Episode 390, Reward: 14.60, Running Avg (50): 9.43
# Episode 400, Reward: 1.93, Running Avg (50): 9.98
# update with length 2000
# Episode 410, Reward: 13.38, Running Avg (50): 9.78
# Episode 420, Reward: 1.85, Running Avg (50): 9.49
# Episode 430, Reward: 1.91, Running Avg (50): 10.24
# Episode 440, Reward: 19.13, Running Avg (50): 9.78
# Episode 450, Reward: 6.15, Running Avg (50): 10.72
# Episode 460, Reward: 13.65, Running Avg (50): 12.23
# Episode 470, Reward: 22.49, Running Avg (50): 12.90
# Episode 480, Reward: 1.91, Running Avg (50): 13.08
# Episode 490, Reward: 3.31, Running Avg (50): 13.36
# Episode 500, Reward: 1.71, Running Avg (50): 12.14
# Episode 510, Reward: 2.90, Running Avg (50): 10.69
# Episode 520, Reward: 1.88, Running Avg (50): 10.52
# Episode 530, Reward: 1.65, Running Avg (50): 9.81
# Episode 540, Reward: 12.18, Running Avg (50): 9.27
# update with length 2000
# Episode 550, Reward: 3.18, Running Avg (50): 9.26
# Episode 560, Reward: 21.68, Running Avg (50): 10.78
# Episode 570, Reward: 4.17, Running Avg (50): 10.62
# Episode 580, Reward: 31.14, Running Avg (50): 12.73
# Episode 590, Reward: 11.99, Running Avg (50): 13.00
# Episode 600, Reward: 27.72, Running Avg (50): 14.63
# Episode 610, Reward: 1.75, Running Avg (50): 13.52
# Episode 620, Reward: 11.05, Running Avg (50): 13.71
# Episode 630, Reward: 3.89, Running Avg (50): 11.79
# Episode 640, Reward: 17.99, Running Avg (50): 12.89
# Episode 650, Reward: 14.06, Running Avg (50): 12.72
# Episode 660, Reward: 19.12, Running Avg (50): 12.95
# update with length 2000
# Episode 670, Reward: 31.17, Running Avg (50): 13.25
# Episode 680, Reward: 3.75, Running Avg (50): 14.43
# Episode 690, Reward: 10.78, Running Avg (50): 13.11
# Episode 700, Reward: 1.84, Running Avg (50): 14.03
# Episode 710, Reward: 4.96, Running Avg (50): 13.64
# Episode 720, Reward: 9.86, Running Avg (50): 13.26
# Episode 730, Reward: 6.38, Running Avg (50): 13.39
# Episode 740, Reward: 22.81, Running Avg (50): 13.96
# Episode 750, Reward: 11.04, Running Avg (50): 13.31
# Episode 760, Reward: 6.09, Running Avg (50): 14.23
# Episode 770, Reward: 17.92, Running Avg (50): 13.25
# Episode 780, Reward: 2.84, Running Avg (50): 12.21
# update with length 2000
# Episode 790, Reward: 1.95, Running Avg (50): 10.87
# Episode 800, Reward: 7.85, Running Avg (50): 9.72
# Episode 810, Reward: 14.75, Running Avg (50): 9.81
# Episode 820, Reward: 8.79, Running Avg (50): 9.24
# Episode 830, Reward: 9.88, Running Avg (50): 9.10
# Episode 840, Reward: 11.86, Running Avg (50): 10.43
# Episode 850, Reward: 13.37, Running Avg (50): 10.62
# Episode 860, Reward: 13.11, Running Avg (50): 9.79
# Episode 870, Reward: 8.02, Running Avg (50): 11.27
# Episode 880, Reward: 32.68, Running Avg (50): 12.03
# Episode 890, Reward: 3.95, Running Avg (50): 11.80
# Episode 900, Reward: 8.96, Running Avg (50): 10.77
# Episode 910, Reward: 4.88, Running Avg (50): 10.92
# Episode 920, Reward: 4.75, Running Avg (50): 10.30
# Episode 930, Reward: 17.89, Running Avg (50): 9.55
# update with length 2000
# Episode 940, Reward: 9.31, Running Avg (50): 9.02
# Episode 950, Reward: 6.50, Running Avg (50): 9.50
# Episode 960, Reward: 4.69, Running Avg (50): 9.74
# Episode 970, Reward: 6.56, Running Avg (50): 10.12
# Episode 980, Reward: 2.64, Running Avg (50): 10.30
# Episode 990, Reward: 4.20, Running Avg (50): 10.92
# Episode 1000, Reward: 6.79, Running Avg (50): 11.69
# Episode 1010, Reward: 2.62, Running Avg (50): 11.38
# Episode 1020, Reward: 4.83, Running Avg (50): 11.11
# Episode 1030, Reward: 7.13, Running Avg (50): 11.58
# Episode 1040, Reward: 2.07, Running Avg (50): 10.87
# Episode 1050, Reward: 3.00, Running Avg (50): 10.44
# Episode 1060, Reward: 2.93, Running Avg (50): 10.68
# Episode 1070, Reward: 3.91, Running Avg (50): 10.11
# update with length 2000
# Episode 1080, Reward: 5.73, Running Avg (50): 9.88
# Episode 1090, Reward: 10.13, Running Avg (50): 10.14
# Episode 1100, Reward: 12.94, Running Avg (50): 10.42
# Episode 1110, Reward: 31.13, Running Avg (50): 11.25
# Episode 1120, Reward: 22.36, Running Avg (50): 11.69
# Episode 1130, Reward: 3.89, Running Avg (50): 12.36
# Episode 1140, Reward: 7.99, Running Avg (50): 11.38
# Episode 1150, Reward: 6.38, Running Avg (50): 11.93
# Episode 1160, Reward: 3.01, Running Avg (50): 9.95
# Episode 1170, Reward: 3.89, Running Avg (50): 10.15
# Episode 1180, Reward: 1.58, Running Avg (50): 9.10
# Episode 1190, Reward: 11.50, Running Avg (50): 9.57
# Episode 1200, Reward: 31.86, Running Avg (50): 8.94
# Episode 1210, Reward: 1.87, Running Avg (50): 9.22
# Episode 1220, Reward: 15.88, Running Avg (50): 9.94
# update with length 2000
# Episode 1230, Reward: 2.82, Running Avg (50): 10.59
# Episode 1240, Reward: 3.02, Running Avg (50): 11.76
# Episode 1250, Reward: 22.95, Running Avg (50): 12.56
# Episode 1260, Reward: 4.31, Running Avg (50): 13.25
# Episode 1270, Reward: 19.32, Running Avg (50): 12.83
# Episode 1280, Reward: 6.07, Running Avg (50): 12.20
# Episode 1290, Reward: 31.18, Running Avg (50): 11.75
# Episode 1300, Reward: 24.09, Running Avg (50): 12.95
# Episode 1310, Reward: 10.46, Running Avg (50): 14.21
# Episode 1320, Reward: 28.64, Running Avg (50): 13.86
# Episode 1330, Reward: 23.06, Running Avg (50): 15.39
# Episode 1340, Reward: 3.64, Running Avg (50): 15.26
# update with length 2000
# Episode 1350, Reward: 31.89, Running Avg (50): 13.46
# Episode 1360, Reward: 4.02, Running Avg (50): 11.92
# Episode 1370, Reward: 8.51, Running Avg (50): 12.42
# Episode 1380, Reward: 30.74, Running Avg (50): 11.41
# Episode 1390, Reward: 10.62, Running Avg (50): 11.48
# Episode 1400, Reward: 31.64, Running Avg (50): 12.68
# Episode 1410, Reward: 6.38, Running Avg (50): 13.15
# Episode 1420, Reward: 32.62, Running Avg (50): 14.38
# Episode 1430, Reward: 10.80, Running Avg (50): 14.83
# Episode 1440, Reward: 3.77, Running Avg (50): 15.66
# Episode 1450, Reward: 15.71, Running Avg (50): 14.09
# Episode 1460, Reward: 4.75, Running Avg (50): 13.32
# update with length 2000
# Episode 1470, Reward: 2.66, Running Avg (50): 11.35
# Episode 1480, Reward: 20.37, Running Avg (50): 11.27
# Episode 1490, Reward: 8.91, Running Avg (50): 10.91
# Episode 1500, Reward: 2.22, Running Avg (50): 10.99
# Training scenario: Fast
# Box(-inf, inf, (5, 5), float32)
# Episode 10, Reward: 4.36, Running Avg (50): 8.39
# Episode 20, Reward: 16.76, Running Avg (50): 8.68
# Episode 30, Reward: 17.24, Running Avg (50): 9.88
# Episode 40, Reward: 5.44, Running Avg (50): 9.45
# Episode 50, Reward: 7.51, Running Avg (50): 9.96
# Episode 60, Reward: 5.93, Running Avg (50): 10.39
# Episode 70, Reward: 18.40, Running Avg (50): 11.04
# Episode 80, Reward: 8.64, Running Avg (50): 9.54
# Episode 90, Reward: 15.58, Running Avg (50): 9.98
# Episode 100, Reward: 6.67, Running Avg (50): 9.57
# Episode 110, Reward: 8.04, Running Avg (50): 9.08
# Episode 120, Reward: 10.16, Running Avg (50): 9.09
# Episode 130, Reward: 28.71, Running Avg (50): 10.40
# update with length 2000
# Episode 140, Reward: 10.98, Running Avg (50): 10.49
# Episode 150, Reward: 5.67, Running Avg (50): 11.06
# Episode 160, Reward: 18.84, Running Avg (50): 12.52
# Episode 170, Reward: 2.16, Running Avg (50): 12.25
# Episode 180, Reward: 28.98, Running Avg (50): 12.39
# Episode 190, Reward: 23.67, Running Avg (50): 14.25
# Episode 200, Reward: 27.40, Running Avg (50): 14.31
# Episode 210, Reward: 5.80, Running Avg (50): 13.00
# Episode 220, Reward: 27.82, Running Avg (50): 13.37
# Episode 230, Reward: 4.42, Running Avg (50): 12.69
# update with length 2000
# Episode 240, Reward: 11.33, Running Avg (50): 10.85
# Episode 250, Reward: 28.33, Running Avg (50): 11.31
# Episode 260, Reward: 5.07, Running Avg (50): 11.66
# Episode 270, Reward: 26.38, Running Avg (50): 11.36
# Episode 280, Reward: 7.82, Running Avg (50): 12.36
# Episode 290, Reward: 7.56, Running Avg (50): 12.15
# Episode 300, Reward: 16.67, Running Avg (50): 13.14
# Episode 310, Reward: 26.64, Running Avg (50): 13.86
# Episode 320, Reward: 4.40, Running Avg (50): 13.97
# Episode 330, Reward: 28.16, Running Avg (50): 13.68
# update with length 2000
# Episode 340, Reward: 28.96, Running Avg (50): 15.59
# Episode 350, Reward: 3.67, Running Avg (50): 13.87
# Episode 360, Reward: 2.22, Running Avg (50): 13.19
# Episode 370, Reward: 2.96, Running Avg (50): 13.78
# Episode 380, Reward: 25.20, Running Avg (50): 13.58
# Episode 390, Reward: 19.13, Running Avg (50): 12.82
# Episode 400, Reward: 15.89, Running Avg (50): 12.86
# Episode 410, Reward: 28.02, Running Avg (50): 14.73
# Episode 420, Reward: 25.11, Running Avg (50): 15.24
# Episode 430, Reward: 29.18, Running Avg (50): 15.81
# update with length 2000
# Episode 440, Reward: 27.36, Running Avg (50): 14.79
# Episode 450, Reward: 27.44, Running Avg (50): 15.39
# Episode 460, Reward: 2.73, Running Avg (50): 14.53
# Episode 470, Reward: 27.47, Running Avg (50): 13.17
# Episode 480, Reward: 5.11, Running Avg (50): 12.91
# Episode 490, Reward: 1.38, Running Avg (50): 14.85
# Episode 500, Reward: 1.51, Running Avg (50): 15.44
# Episode 510, Reward: 15.98, Running Avg (50): 15.22
# Episode 520, Reward: 7.27, Running Avg (50): 14.86
# update with length 2000
# Episode 530, Reward: 23.27, Running Avg (50): 14.95
# Episode 540, Reward: 8.27, Running Avg (50): 12.05
# Episode 550, Reward: 2.73, Running Avg (50): 10.63
# Episode 560, Reward: 17.29, Running Avg (50): 11.15
# Episode 570, Reward: 1.33, Running Avg (50): 11.73
# Episode 580, Reward: 6.51, Running Avg (50): 12.34
# Episode 590, Reward: 24.78, Running Avg (50): 13.96
# Episode 600, Reward: 27.64, Running Avg (50): 13.97
# Episode 610, Reward: 4.29, Running Avg (50): 12.76
# Episode 620, Reward: 19.00, Running Avg (50): 14.21
# update with length 2000
# Episode 630, Reward: 8.07, Running Avg (50): 14.84
# Episode 640, Reward: 5.80, Running Avg (50): 14.63
# Episode 650, Reward: 3.38, Running Avg (50): 14.96
# Episode 660, Reward: 4.80, Running Avg (50): 14.35
# Episode 670, Reward: 5.02, Running Avg (50): 12.92
# Episode 680, Reward: 4.18, Running Avg (50): 11.49
# Episode 690, Reward: 1.33, Running Avg (50): 11.27
# Episode 700, Reward: 2.87, Running Avg (50): 10.84
# Episode 710, Reward: 2.02, Running Avg (50): 11.90
# Episode 720, Reward: 27.02, Running Avg (50): 12.78
# Episode 730, Reward: 2.00, Running Avg (50): 13.09
# update with length 2000
# Episode 740, Reward: 1.51, Running Avg (50): 12.82
# Episode 750, Reward: 14.78, Running Avg (50): 13.32
# Episode 760, Reward: 4.93, Running Avg (50): 13.84
# Episode 770, Reward: 17.47, Running Avg (50): 13.53
# Episode 780, Reward: 16.22, Running Avg (50): 13.30
# Episode 790, Reward: 15.58, Running Avg (50): 13.33
# Episode 800, Reward: 15.07, Running Avg (50): 13.57
# Episode 810, Reward: 3.49, Running Avg (50): 12.17
# Episode 820, Reward: 2.09, Running Avg (50): 10.84
# Episode 830, Reward: 8.40, Running Avg (50): 11.62
# update with length 2000
# Episode 840, Reward: 11.73, Running Avg (50): 12.98
# Episode 850, Reward: 13.53, Running Avg (50): 12.46
# Episode 860, Reward: 27.58, Running Avg (50): 14.60
# Episode 870, Reward: 22.22, Running Avg (50): 15.45
# Episode 880, Reward: 16.04, Running Avg (50): 14.75
# Episode 890, Reward: 12.33, Running Avg (50): 13.06
# Episode 900, Reward: 5.62, Running Avg (50): 12.84
# Episode 910, Reward: 27.27, Running Avg (50): 11.82
# Episode 920, Reward: 28.78, Running Avg (50): 13.21
# Episode 930, Reward: 27.58, Running Avg (50): 14.01
# update with length 2000
# Episode 940, Reward: 27.64, Running Avg (50): 15.49
# Episode 950, Reward: 2.69, Running Avg (50): 15.67
# Episode 960, Reward: 27.02, Running Avg (50): 15.12
# Episode 970, Reward: 29.00, Running Avg (50): 14.93
# Episode 980, Reward: 10.24, Running Avg (50): 13.86
# Episode 990, Reward: 27.09, Running Avg (50): 14.36
# Episode 1000, Reward: 4.78, Running Avg (50): 14.99
# Episode 1010, Reward: 7.38, Running Avg (50): 15.76
# Episode 1020, Reward: 16.36, Running Avg (50): 14.79
# update with length 2000
# Episode 1030, Reward: 10.58, Running Avg (50): 14.45
# Episode 1040, Reward: 2.24, Running Avg (50): 12.39
# Episode 1050, Reward: 28.49, Running Avg (50): 12.19
# Episode 1060, Reward: 3.64, Running Avg (50): 11.98
# Episode 1070, Reward: 5.69, Running Avg (50): 12.09
# Episode 1080, Reward: 8.76, Running Avg (50): 12.44
# Episode 1090, Reward: 28.00, Running Avg (50): 12.99
# Episode 1100, Reward: 10.02, Running Avg (50): 13.24
# Episode 1110, Reward: 27.60, Running Avg (50): 13.90
# Episode 1120, Reward: 22.44, Running Avg (50): 13.98
# update with length 2000
# Episode 1130, Reward: 7.62, Running Avg (50): 13.57
# Episode 1140, Reward: 27.44, Running Avg (50): 13.98
# Episode 1150, Reward: 9.47, Running Avg (50): 13.03
# Episode 1160, Reward: 7.98, Running Avg (50): 12.80
# Episode 1170, Reward: 18.91, Running Avg (50): 13.11
# Episode 1180, Reward: 27.02, Running Avg (50): 13.85
# Episode 1190, Reward: 27.31, Running Avg (50): 14.65
# Episode 1200, Reward: 2.16, Running Avg (50): 15.53
# Episode 1210, Reward: 27.91, Running Avg (50): 14.67
# update with length 2000
# Episode 1220, Reward: 19.73, Running Avg (50): 15.48
# Episode 1230, Reward: 28.31, Running Avg (50): 15.94
# Episode 1240, Reward: 4.42, Running Avg (50): 15.87
# Episode 1250, Reward: 18.73, Running Avg (50): 16.17
# Episode 1260, Reward: 2.07, Running Avg (50): 16.56
# Episode 1270, Reward: 5.60, Running Avg (50): 16.66
# Episode 1280, Reward: 27.76, Running Avg (50): 17.07
# Episode 1290, Reward: 27.71, Running Avg (50): 17.91
# update with length 2000
# Episode 1300, Reward: 4.67, Running Avg (50): 17.34
# Episode 1310, Reward: 7.40, Running Avg (50): 18.14
# Episode 1320, Reward: 17.38, Running Avg (50): 17.72
# Episode 1330, Reward: 23.71, Running Avg (50): 17.38
# Episode 1340, Reward: 23.20, Running Avg (50): 16.17
# Episode 1350, Reward: 2.76, Running Avg (50): 16.04
# Episode 1360, Reward: 19.11, Running Avg (50): 15.68
# Episode 1370, Reward: 27.16, Running Avg (50): 15.99
# Episode 1380, Reward: 27.47, Running Avg (50): 14.67
# update with length 2000
# Episode 1390, Reward: 19.76, Running Avg (50): 15.39
# Episode 1400, Reward: 19.47, Running Avg (50): 15.99
# Episode 1410, Reward: 26.98, Running Avg (50): 15.94
# Episode 1420, Reward: 9.44, Running Avg (50): 15.05
# Episode 1430, Reward: 4.29, Running Avg (50): 15.81
# Episode 1440, Reward: 21.44, Running Avg (50): 14.74
# Episode 1450, Reward: 27.47, Running Avg (50): 13.72
# Episode 1460, Reward: 27.00, Running Avg (50): 14.36
# update with length 2000
# Episode 1470, Reward: 3.33, Running Avg (50): 15.19
# Episode 1480, Reward: 26.91, Running Avg (50): 17.14
# Episode 1490, Reward: 27.53, Running Avg (50): 18.22
# Episode 1500, Reward: 5.51, Running Avg (50): 19.48

# %%
# if not working, try to normalize the rewards.

# %%
import numpy as np
import pandas as pd

def evaluate_model(env, model, episodes=50, max_steps=1000, is_ppo=True):
    rewards = []
    collisions = []

    for _ in range(episodes):
        state, _ = env.reset()
        total_reward = 0.0
        collision_count = 0
        done = False
        steps = 0

        while not done and steps < max_steps:
            if is_ppo:
                action = model.select_action_eval(state)
            else:
                q_vals = model.predict(state[np.newaxis], verbose=0)[0]
                action = int(np.argmax(q_vals))

            next_state, reward, terminated, truncated, info = env.step(action)
            done = terminated or truncated

            total_reward += reward
            if info.get("crashed", False) or reward < 0:
                collision_count += 1

            state = next_state
            steps += 1

        rewards.append(total_reward)
        collisions.append(collision_count)

    avg_collisions = np.mean(collisions)
    return rewards, avg_collisions

def evaluate_all_agents(trained_agents, driver_configs, base_config, episodes=50, is_ppo=True):
    results = []

    for label, agent in trained_agents.items():
        print(f"\nEvaluating agent: {label}")

        cfg = base_config.copy()
        cfg.update(driver_configs[label])
        env = gym.make("highway-v0", render_mode=None).unwrapped
        env.configure(cfg)

        rewards, avg_collisions = evaluate_model(env, agent, episodes=episodes, is_ppo=is_ppo)

        results.append({
            "behavior": label,
            "mean_reward": np.mean(rewards),
            "std_reward": np.std(rewards),
            "avg_collisions": avg_collisions
        })

        env.close()

    df = pd.DataFrame(results)
    print("\nEvaluation Results:")
    print(df.to_string(index=False))
    return df

# %%
df = evaluate_all_agents(trained_agents, SCENARIOS, BASE_CONFIG, episodes=50, is_ppo=True)
# Out:
# Evaluating agent: Slow
#
# Evaluating agent: Normal
#
# Evaluating agent: Fast
#
# Evaluation Results:
# behavior  mean_reward  std_reward  avg_collisions
#     Slow    14.422114    8.977593            1.00
#   Normal    11.248281    7.027024            1.00
#     Fast     9.872444    7.236953            0.94
