# %%
import torch
print(torch.cuda.is_available())
print(torch.cuda.get_device_name(0) if torch.cuda.is_available() else "No CUDA device")
# Out:
# True
# NVIDIA GeForce RTX 4060 Laptop GPU

# %%
import torch
import torch.nn as nn
from torch.distributions import Categorical

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")

class RolloutBuffer:
    def __init__(self):
        self.actions = []
        self.states = []
        self.logprobs = []
        self.rewards = []
        self.state_values = []
        self.is_terminals = []

    def clear(self):
        self.actions.clear()
        self.states.clear()
        self.logprobs.clear()
        self.rewards.clear()
        self.state_values.clear()
        self.is_terminals.clear()

class ActorCritic(nn.Module):
    def __init__(self, state_dim, action_dim):
        super(ActorCritic, self).__init__()

        self.actor = nn.Sequential(
            nn.Linear(state_dim, 64),
            nn.Tanh(),
            nn.Linear(64, 64),
            nn.Tanh(),
            nn.Linear(64, action_dim),
            nn.Softmax(dim=-1)
        )

        self.critic = nn.Sequential(
            nn.Linear(state_dim, 64),
            nn.Tanh(),
            nn.Linear(64, 64),
            nn.Tanh(),
            nn.Linear(64, 1)
        )

    def act(self, state, deterministic=False):
        action_probs = self.actor(state)
        if deterministic:
            action = torch.argmax(action_probs, dim=-1)
            action_logprob = torch.log(action_probs.gather(1, action.unsqueeze(-1)).squeeze(-1))
        else:
            dist = Categorical(action_probs)
            action = dist.sample()
            action_logprob = dist.log_prob(action)
        state_value = self.critic(state)
        return action, action_logprob, state_value

    def evaluate(self, states, actions):
        action_probs = self.actor(states)
        dist = Categorical(action_probs)
        action_logprobs = dist.log_prob(actions)
        dist_entropy = dist.entropy()
        state_values = self.critic(states).squeeze(-1)
        return action_logprobs, state_values, dist_entropy

class PPO:
    def __init__(self, state_dim, action_dim, lr_actor, lr_critic, gamma, K_epochs, eps_clip):
        self.gamma = gamma
        self.eps_clip = eps_clip
        self.K_epochs = K_epochs

        self.buffer = RolloutBuffer()

        self.policy = ActorCritic(state_dim, action_dim).to(device)
        self.optimizer = torch.optim.Adam([
            {'params': self.policy.actor.parameters(), 'lr': lr_actor},
            {'params': self.policy.critic.parameters(), 'lr': lr_critic}
        ])

        self.policy_old = ActorCritic(state_dim, action_dim).to(device)
        self.policy_old.load_state_dict(self.policy.state_dict())
        self.MseLoss = nn.MSELoss()

    def select_action(self, state):
        state = torch.FloatTensor(state).flatten().unsqueeze(0).to(device)
        with torch.no_grad():
            action, action_logprob, state_value = self.policy_old.act(state, deterministic=False)

        self.buffer.states.append(state.squeeze(0))
        self.buffer.actions.append(action)
        self.buffer.logprobs.append(action_logprob)
        self.buffer.state_values.append(state_value.squeeze())

        return action.item()

    def update(self, mini_batch_size=256):
        # Compute discounted rewards-to-go
        rewards = []
        discounted_reward = 0
        for reward, is_terminal in zip(reversed(self.buffer.rewards), reversed(self.buffer.is_terminals)):
            discounted_reward = reward + (self.gamma * discounted_reward * (1 - is_terminal))
            rewards.insert(0, discounted_reward)
        rewards = torch.tensor(rewards, dtype=torch.float32).to(device)
        # rewards = (rewards - rewards.mean()) / (rewards.std() + 1e-7)

        # Convert rollout buffer to tensors
        old_states = torch.stack(self.buffer.states).to(device)
        old_actions = torch.stack(self.buffer.actions).to(device)
        old_logprobs = torch.stack(self.buffer.logprobs).to(device)
        old_state_values = torch.stack(self.buffer.state_values).to(device)
        advantages = rewards - old_state_values.detach()
        # advantages = (advantages - advantages.mean()) / (advantages.std() + 1e-8)

        # Total data size
        dataset_size = old_states.size(0)
        for _ in range(self.K_epochs):
            # Shuffle indices
            indices = torch.randperm(dataset_size)
            for start in range(0, dataset_size, mini_batch_size):
                end = start + mini_batch_size
                mb_idx = indices[start:end]

                mb_states = old_states[mb_idx]
                mb_actions = old_actions[mb_idx]
                mb_logprobs = old_logprobs[mb_idx]
                mb_advantages = advantages[mb_idx]
                mb_returns = rewards[mb_idx]

                # Evaluate with current policy
                logprobs, state_values, dist_entropy = self.policy.evaluate(mb_states, mb_actions)
                ratios = torch.exp(logprobs - mb_logprobs.detach())

                # Clipped objective
                surr1 = ratios * mb_advantages
                surr2 = torch.clamp(ratios, 1 - self.eps_clip, 1 + self.eps_clip) * mb_advantages
                loss = -torch.min(surr1, surr2) \
                    + 0.5 * self.MseLoss(state_values, mb_returns) \
                    - 0.01 * dist_entropy

                self.optimizer.zero_grad()
                loss.mean().backward()
                self.optimizer.step()

        self.policy_old.load_state_dict(self.policy.state_dict())
        self.buffer.clear()

        
    def select_action_eval(self, state):
        state = torch.FloatTensor(state).flatten().unsqueeze(0).to(device)
        with torch.no_grad():
            action, _, _ = self.policy_old.act(state, deterministic=True)
        return action.item()
# Out:
# Using device: cuda

# %%
import gymnasium as gym
import highway_env
import numpy as np
import matplotlib.pyplot as plt

BASE_CONFIG = {
    "observation":       {"type": "Kinematics"},
    "action":            {"type": "DiscreteMetaAction"},
    "lanes_count":       4,
    "controlled_vehicles": 1,
    "duration":          40,
    "ego_spacing":       2,
    "vehicles_density":  1,
    "collision_reward":  -1,
    "right_lane_reward": 0.1,
    "high_speed_reward": 0.4,
    "lane_change_reward": 0,
    "normalize_reward":  True,
    "offroad_terminal":  False,
}

# %%
SCENARIOS = {
    "Slow":   {"reward_speed_range": [10, 20]},
    "Normal": {"reward_speed_range": [20, 30]},
    "Fast":   {"reward_speed_range": [30, 40]},
}

def train(cfg, label=""):
    env = gym.make("highway-v0", render_mode="rgb_array").unwrapped
    env.configure(cfg)
    print(f"\nTraining scenario: {label}")
    print(env.observation_space)
    
    state_dim = np.prod(env.observation_space.shape)
    action_dim = env.action_space.n

    # PPO hyperparameters
    max_episodes = 1000
    max_ep_len = 1000
    update_timestep = 1000
    K_epochs = 20
    eps_clip = 0.2
    gamma = 0.99
    lr_actor = 0.0003
    lr_critic = 0.0003

    episode_reward_history = []
    running_rewards = []
    last_n_reward = 50

    ppo_agent = PPO(state_dim, action_dim, lr_actor, lr_critic, gamma, K_epochs, eps_clip)

    time_step = 0
    i_episode = 0

    while i_episode < max_episodes:
        obs, _ = env.reset()
        current_ep_reward = 0

        for _ in range(max_ep_len):
            action = ppo_agent.select_action(obs)
            next_obs, reward, done, truncated, info = env.step(action)

            ppo_agent.buffer.rewards.append(reward)
            ppo_agent.buffer.is_terminals.append(done or truncated)

            time_step += 1
            current_ep_reward += reward

            if time_step % update_timestep == 0:
                print("update with length "+ str(len(ppo_agent.buffer.rewards)))
                ppo_agent.update()

            obs = next_obs

            if done or truncated:
                break

        i_episode += 1
        episode_reward_history.append(current_ep_reward)

        running_reward = (
            np.mean(episode_reward_history[-last_n_reward:])
            if len(episode_reward_history) > last_n_reward
            else np.mean(episode_reward_history)
        )
        running_rewards.append(running_reward)
        if i_episode % 10 == 0:
            print(f"Episode {i_episode}, Reward: {current_ep_reward:.2f}, Running Avg ({last_n_reward}): {running_reward:.2f}")

    plt.figure(figsize=(10, 5))
    plt.plot(episode_reward_history, label="Episode Reward")
    plt.plot(running_rewards, label=f"Running Avg (last {last_n_reward})", linewidth=2)
    plt.xlabel("Episode")
    plt.ylabel("Reward")
    plt.title(f"PPO Training Rewards - {label}")
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()

    env.close()
    return ppo_agent

if __name__ == "__main__":
    trained_agents = {}
    for label, scenario_cfg in SCENARIOS.items():
        cfg = BASE_CONFIG.copy()
        cfg.update(scenario_cfg)
        agent = train(cfg, label)
        torch.cuda.empty_cache()
        trained_agents[label] = agent
# Out:
# Training scenario: Slow
# Box(-inf, inf, (5, 5), float32)
# Episode 10, Reward: 22.95, Running Avg (50): 8.33
# Episode 20, Reward: 5.93, Running Avg (50): 10.23
# Episode 30, Reward: 4.09, Running Avg (50): 10.31
# Episode 40, Reward: 3.08, Running Avg (50): 10.49
# Episode 50, Reward: 25.65, Running Avg (50): 12.02
# Episode 60, Reward: 4.09, Running Avg (50): 12.74
# Episode 70, Reward: 2.83, Running Avg (50): 11.86
# update with length 1000
# Episode 80, Reward: 12.11, Running Avg (50): 12.32
# Episode 90, Reward: 20.84, Running Avg (50): 13.40
# Episode 100, Reward: 34.93, Running Avg (50): 12.49
# Episode 110, Reward: 5.93, Running Avg (50): 11.98
# Episode 120, Reward: 21.24, Running Avg (50): 14.22
# Episode 130, Reward: 9.70, Running Avg (50): 14.38
# Episode 140, Reward: 39.48, Running Avg (50): 14.89
# update with length 1000
# Episode 150, Reward: 19.06, Running Avg (50): 14.66
# Episode 160, Reward: 39.62, Running Avg (50): 16.08
# Episode 170, Reward: 39.35, Running Avg (50): 14.80
# Episode 180, Reward: 3.09, Running Avg (50): 15.79
# Episode 190, Reward: 39.33, Running Avg (50): 16.04
# Episode 200, Reward: 5.04, Running Avg (50): 16.52
# update with length 1000
# Episode 210, Reward: 20.93, Running Avg (50): 17.13
# Episode 220, Reward: 27.97, Running Avg (50): 20.06
# Episode 230, Reward: 16.97, Running Avg (50): 19.83
# Episode 240, Reward: 39.30, Running Avg (50): 19.87
# update with length 1000
# Episode 250, Reward: 9.92, Running Avg (50): 20.71
# Episode 260, Reward: 18.87, Running Avg (50): 22.57
# Episode 270, Reward: 21.75, Running Avg (50): 21.90
# Episode 280, Reward: 37.88, Running Avg (50): 22.82
# update with length 1000
# Episode 290, Reward: 39.95, Running Avg (50): 23.85
# Episode 300, Reward: 22.97, Running Avg (50): 23.52
# Episode 310, Reward: 6.71, Running Avg (50): 20.97
# Episode 320, Reward: 19.99, Running Avg (50): 22.95
# update with length 1000
# Episode 330, Reward: 39.61, Running Avg (50): 24.48
# Episode 340, Reward: 25.84, Running Avg (50): 24.62
# Episode 350, Reward: 2.07, Running Avg (50): 24.57
# Episode 360, Reward: 25.62, Running Avg (50): 25.88
# update with length 1000
# Episode 370, Reward: 3.27, Running Avg (50): 23.93
# Episode 380, Reward: 6.13, Running Avg (50): 22.31
# Episode 390, Reward: 9.00, Running Avg (50): 20.25
# Episode 400, Reward: 3.11, Running Avg (50): 22.88
# update with length 1000
# Episode 410, Reward: 5.23, Running Avg (50): 22.54
# Episode 420, Reward: 29.65, Running Avg (50): 22.48
# Episode 430, Reward: 33.06, Running Avg (50): 24.68
# Episode 440, Reward: 14.95, Running Avg (50): 25.24
# update with length 1000
# Episode 450, Reward: 39.81, Running Avg (50): 23.87
# Episode 460, Reward: 18.26, Running Avg (50): 24.46
# Episode 470, Reward: 15.13, Running Avg (50): 24.39
# Episode 480, Reward: 34.63, Running Avg (50): 22.79
# update with length 1000
# Episode 490, Reward: 15.33, Running Avg (50): 25.08
# Episode 500, Reward: 4.33, Running Avg (50): 24.01
# Episode 510, Reward: 38.46, Running Avg (50): 25.09
# Episode 520, Reward: 39.52, Running Avg (50): 26.32
# update with length 1000
# Episode 530, Reward: 38.08, Running Avg (50): 27.96
# Episode 540, Reward: 2.22, Running Avg (50): 25.68
# Episode 550, Reward: 39.75, Running Avg (50): 27.60
# update with length 1000
# Episode 560, Reward: 20.27, Running Avg (50): 28.07
# Episode 570, Reward: 13.51, Running Avg (50): 27.26
# Episode 580, Reward: 39.48, Running Avg (50): 25.68
# Episode 590, Reward: 13.15, Running Avg (50): 26.81
# update with length 1000
# Episode 600, Reward: 39.72, Running Avg (50): 26.67
# Episode 610, Reward: 6.18, Running Avg (50): 25.85
# Episode 620, Reward: 38.64, Running Avg (50): 25.57
# Episode 630, Reward: 38.08, Running Avg (50): 26.75
# update with length 1000
# Episode 640, Reward: 38.08, Running Avg (50): 27.47
# Episode 650, Reward: 28.08, Running Avg (50): 27.62
# Episode 660, Reward: 39.89, Running Avg (50): 27.00
# update with length 1000
# Episode 670, Reward: 19.66, Running Avg (50): 26.46
# Episode 680, Reward: 16.49, Running Avg (50): 25.41
# Episode 690, Reward: 5.07, Running Avg (50): 25.83
# Episode 700, Reward: 5.78, Running Avg (50): 24.99
# update with length 1000
# Episode 710, Reward: 2.18, Running Avg (50): 25.00
# Episode 720, Reward: 38.14, Running Avg (50): 25.89
# Episode 730, Reward: 7.04, Running Avg (50): 25.01
# Episode 740, Reward: 6.60, Running Avg (50): 23.31
# update with length 1000
# Episode 750, Reward: 23.85, Running Avg (50): 25.21
# Episode 760, Reward: 39.93, Running Avg (50): 26.94
# Episode 770, Reward: 23.33, Running Avg (50): 27.37
# update with length 1000
# Episode 780, Reward: 37.88, Running Avg (50): 28.27
# Episode 790, Reward: 39.19, Running Avg (50): 28.30
# Episode 800, Reward: 38.03, Running Avg (50): 28.51
# update with length 1000
# Episode 810, Reward: 38.81, Running Avg (50): 28.35
# Episode 820, Reward: 38.36, Running Avg (50): 29.04
# Episode 830, Reward: 38.36, Running Avg (50): 29.12
# Episode 840, Reward: 39.70, Running Avg (50): 30.65
# update with length 1000
# Episode 850, Reward: 3.86, Running Avg (50): 28.72
# Episode 860, Reward: 39.52, Running Avg (50): 28.89
# Episode 870, Reward: 18.36, Running Avg (50): 28.22
# update with length 1000
# Episode 880, Reward: 31.78, Running Avg (50): 29.55
# Episode 890, Reward: 13.68, Running Avg (50): 29.70
# Episode 900, Reward: 39.44, Running Avg (50): 32.54
# update with length 1000
# Episode 910, Reward: 37.76, Running Avg (50): 32.40
# Episode 920, Reward: 38.26, Running Avg (50): 33.69
# Episode 930, Reward: 38.99, Running Avg (50): 33.53
# update with length 1000
# Episode 940, Reward: 39.77, Running Avg (50): 34.57
# Episode 950, Reward: 38.28, Running Avg (50): 34.05
# Episode 960, Reward: 2.96, Running Avg (50): 33.13
# update with length 1000
# Episode 970, Reward: 7.59, Running Avg (50): 32.24
# Episode 980, Reward: 39.07, Running Avg (50): 32.62
# Episode 990, Reward: 38.44, Running Avg (50): 32.64
# update with length 1000
# Episode 1000, Reward: 38.91, Running Avg (50): 31.11
# Training scenario: Normal
# Box(-inf, inf, (5, 5), float32)
# Episode 10, Reward: 8.14, Running Avg (50): 13.61
# Episode 20, Reward: 7.40, Running Avg (50): 13.28
# Episode 30, Reward: 28.06, Running Avg (50): 13.04
# Episode 40, Reward: 19.76, Running Avg (50): 13.10
# Episode 50, Reward: 2.16, Running Avg (50): 12.60
# Episode 60, Reward: 11.26, Running Avg (50): 11.87
# update with length 1000
# Episode 70, Reward: 7.59, Running Avg (50): 13.12
# Episode 80, Reward: 20.42, Running Avg (50): 13.01
# Episode 90, Reward: 14.72, Running Avg (50): 12.07
# Episode 100, Reward: 5.78, Running Avg (50): 11.89
# Episode 110, Reward: 2.47, Running Avg (50): 12.06
# Episode 120, Reward: 7.57, Running Avg (50): 11.27
# update with length 1000
# Episode 130, Reward: 4.56, Running Avg (50): 11.37
# Episode 140, Reward: 15.86, Running Avg (50): 11.51
# Episode 150, Reward: 3.64, Running Avg (50): 12.00
# Episode 160, Reward: 7.44, Running Avg (50): 12.92
# Episode 170, Reward: 12.35, Running Avg (50): 11.82
# Episode 180, Reward: 20.33, Running Avg (50): 11.98
# update with length 1000
# Episode 190, Reward: 17.02, Running Avg (50): 13.22
# Episode 200, Reward: 12.64, Running Avg (50): 13.78
# Episode 210, Reward: 24.46, Running Avg (50): 12.96
# Episode 220, Reward: 10.31, Running Avg (50): 14.06
# Episode 230, Reward: 7.40, Running Avg (50): 13.55
# Episode 240, Reward: 11.77, Running Avg (50): 12.86
# update with length 1000
# Episode 250, Reward: 1.85, Running Avg (50): 12.63
# Episode 260, Reward: 29.84, Running Avg (50): 12.42
# Episode 270, Reward: 5.11, Running Avg (50): 11.44
# Episode 280, Reward: 32.01, Running Avg (50): 11.70
# Episode 290, Reward: 20.06, Running Avg (50): 11.43
# Episode 300, Reward: 13.78, Running Avg (50): 10.67
# Episode 310, Reward: 3.53, Running Avg (50): 10.78
# update with length 1000
# Episode 320, Reward: 1.86, Running Avg (50): 11.13
# Episode 330, Reward: 6.97, Running Avg (50): 10.42
# Episode 340, Reward: 8.72, Running Avg (50): 10.53
# Episode 350, Reward: 6.29, Running Avg (50): 10.73
# Episode 360, Reward: 5.73, Running Avg (50): 10.88
# Episode 370, Reward: 18.58, Running Avg (50): 11.09
# update with length 1000
# Episode 380, Reward: 1.91, Running Avg (50): 12.41
# Episode 390, Reward: 8.55, Running Avg (50): 11.77
# Episode 400, Reward: 5.40, Running Avg (50): 12.26
# Episode 410, Reward: 20.85, Running Avg (50): 13.14
# Episode 420, Reward: 2.68, Running Avg (50): 13.11
# Episode 430, Reward: 3.27, Running Avg (50): 12.11
# Episode 440, Reward: 13.84, Running Avg (50): 12.47
# update with length 1000
# Episode 450, Reward: 5.53, Running Avg (50): 12.94
# Episode 460, Reward: 2.64, Running Avg (50): 12.85
# Episode 470, Reward: 1.80, Running Avg (50): 12.34
# Episode 480, Reward: 9.18, Running Avg (50): 11.60
# Episode 490, Reward: 9.59, Running Avg (50): 11.84
# Episode 500, Reward: 9.79, Running Avg (50): 12.12
# update with length 1000
# Episode 510, Reward: 9.91, Running Avg (50): 12.56
# Episode 520, Reward: 30.51, Running Avg (50): 13.01
# Episode 530, Reward: 9.93, Running Avg (50): 14.73
# Episode 540, Reward: 22.35, Running Avg (50): 15.45
# Episode 550, Reward: 11.70, Running Avg (50): 16.27
# update with length 1000
# Episode 560, Reward: 7.11, Running Avg (50): 17.15
# Episode 570, Reward: 2.78, Running Avg (50): 16.30
# Episode 580, Reward: 10.46, Running Avg (50): 16.27
# Episode 590, Reward: 1.71, Running Avg (50): 16.59
# Episode 600, Reward: 4.77, Running Avg (50): 13.93
# update with length 1000
# Episode 610, Reward: 6.48, Running Avg (50): 11.62
# Episode 620, Reward: 12.35, Running Avg (50): 12.95
# Episode 630, Reward: 4.91, Running Avg (50): 12.21
# Episode 640, Reward: 32.24, Running Avg (50): 12.46
# Episode 650, Reward: 9.87, Running Avg (50): 13.25
# Episode 660, Reward: 22.11, Running Avg (50): 14.67
# update with length 1000
# Episode 670, Reward: 7.43, Running Avg (50): 14.00
# Episode 680, Reward: 15.84, Running Avg (50): 15.53
# Episode 690, Reward: 16.71, Running Avg (50): 14.30
# Episode 700, Reward: 31.09, Running Avg (50): 14.34
# Episode 710, Reward: 12.43, Running Avg (50): 13.29
# Episode 720, Reward: 3.64, Running Avg (50): 12.25
# update with length 1000
# Episode 730, Reward: 5.50, Running Avg (50): 11.03
# Episode 740, Reward: 9.62, Running Avg (50): 12.67
# Episode 750, Reward: 14.91, Running Avg (50): 11.83
# Episode 760, Reward: 9.77, Running Avg (50): 12.13
# Episode 770, Reward: 17.50, Running Avg (50): 14.34
# update with length 1000
# Episode 780, Reward: 8.35, Running Avg (50): 14.74
# Episode 790, Reward: 26.63, Running Avg (50): 13.48
# Episode 800, Reward: 9.75, Running Avg (50): 14.56
# Episode 810, Reward: 18.13, Running Avg (50): 14.12
# Episode 820, Reward: 16.04, Running Avg (50): 13.22
# Episode 830, Reward: 4.64, Running Avg (50): 12.17
# update with length 1000
# Episode 840, Reward: 5.80, Running Avg (50): 12.95
# Episode 850, Reward: 8.47, Running Avg (50): 12.67
# Episode 860, Reward: 31.66, Running Avg (50): 13.98
# Episode 870, Reward: 3.29, Running Avg (50): 13.78
# Episode 880, Reward: 34.09, Running Avg (50): 15.06
# update with length 1000
# Episode 890, Reward: 23.27, Running Avg (50): 14.62
# Episode 900, Reward: 32.73, Running Avg (50): 15.03
# Episode 910, Reward: 30.26, Running Avg (50): 14.20
# Episode 920, Reward: 12.35, Running Avg (50): 13.82
# Episode 930, Reward: 5.65, Running Avg (50): 12.47
# Episode 940, Reward: 21.95, Running Avg (50): 12.20
# Episode 950, Reward: 3.82, Running Avg (50): 11.60
# update with length 1000
# Episode 960, Reward: 5.20, Running Avg (50): 10.95
# Episode 970, Reward: 29.96, Running Avg (50): 12.17
# Episode 980, Reward: 16.01, Running Avg (50): 13.74
# Episode 990, Reward: 31.93, Running Avg (50): 15.09
# Episode 1000, Reward: 1.97, Running Avg (50): 14.79
# Training scenario: Fast
# Box(-inf, inf, (5, 5), float32)
# Episode 10, Reward: 2.76, Running Avg (50): 7.83
# Episode 20, Reward: 9.51, Running Avg (50): 11.51
# Episode 30, Reward: 3.38, Running Avg (50): 10.86
# Episode 40, Reward: 22.78, Running Avg (50): 11.11
# Episode 50, Reward: 13.29, Running Avg (50): 11.38
# update with length 1000
# Episode 60, Reward: 27.22, Running Avg (50): 12.86
# Episode 70, Reward: 28.44, Running Avg (50): 13.47
# Episode 80, Reward: 7.00, Running Avg (50): 13.84
# Episode 90, Reward: 12.38, Running Avg (50): 14.87
# Episode 100, Reward: 28.40, Running Avg (50): 14.51
# update with length 1000
# Episode 110, Reward: 9.29, Running Avg (50): 13.62
# Episode 120, Reward: 26.98, Running Avg (50): 14.01
# Episode 130, Reward: 17.42, Running Avg (50): 15.03
# Episode 140, Reward: 27.22, Running Avg (50): 15.65
# update with length 1000
# Episode 150, Reward: 8.80, Running Avg (50): 16.25
# Episode 160, Reward: 9.16, Running Avg (50): 17.62
# Episode 170, Reward: 27.00, Running Avg (50): 17.49
# update with length 1000
# Episode 180, Reward: 26.82, Running Avg (50): 18.56
# Episode 190, Reward: 5.11, Running Avg (50): 17.93
# Episode 200, Reward: 20.38, Running Avg (50): 19.23
# Episode 210, Reward: 7.22, Running Avg (50): 19.55
# update with length 1000
# Episode 220, Reward: 27.64, Running Avg (50): 20.03
# Episode 230, Reward: 24.40, Running Avg (50): 20.44
# Episode 240, Reward: 26.91, Running Avg (50): 22.06
# update with length 1000
# Episode 250, Reward: 28.09, Running Avg (50): 22.39
# Episode 260, Reward: 13.24, Running Avg (50): 22.84
# Episode 270, Reward: 27.67, Running Avg (50): 22.88
# update with length 1000
# Episode 280, Reward: 27.56, Running Avg (50): 22.17
# Episode 290, Reward: 28.16, Running Avg (50): 20.63
# Episode 300, Reward: 28.73, Running Avg (50): 19.95
# update with length 1000
# Episode 310, Reward: 26.84, Running Avg (50): 20.86
# Episode 320, Reward: 4.18, Running Avg (50): 19.16
# Episode 330, Reward: 28.07, Running Avg (50): 19.71
# Episode 340, Reward: 27.76, Running Avg (50): 20.57
# update with length 1000
# Episode 350, Reward: 28.76, Running Avg (50): 21.46
# Episode 360, Reward: 28.33, Running Avg (50): 21.34
# Episode 370, Reward: 0.78, Running Avg (50): 22.30
# update with length 1000
# Episode 380, Reward: 27.24, Running Avg (50): 22.84
# Episode 390, Reward: 27.44, Running Avg (50): 23.54
# Episode 400, Reward: 3.00, Running Avg (50): 23.38
# update with length 1000
# Episode 410, Reward: 10.31, Running Avg (50): 22.96
# Episode 420, Reward: 26.80, Running Avg (50): 24.20
# Episode 430, Reward: 4.00, Running Avg (50): 21.10
# update with length 1000
# Episode 440, Reward: 3.00, Running Avg (50): 19.79
# Episode 450, Reward: 28.56, Running Avg (50): 19.80
# Episode 460, Reward: 27.93, Running Avg (50): 19.42
# Episode 470, Reward: 5.82, Running Avg (50): 18.37
# update with length 1000
# Episode 480, Reward: 27.27, Running Avg (50): 20.57
# Episode 490, Reward: 27.22, Running Avg (50): 20.97
# Episode 500, Reward: 14.42, Running Avg (50): 20.65
# update with length 1000
# Episode 510, Reward: 27.76, Running Avg (50): 20.09
# Episode 520, Reward: 9.82, Running Avg (50): 19.26
# Episode 530, Reward: 12.84, Running Avg (50): 19.56
# Episode 540, Reward: 26.98, Running Avg (50): 18.73
# update with length 1000
# Episode 550, Reward: 10.07, Running Avg (50): 18.68
# Episode 560, Reward: 28.20, Running Avg (50): 20.04
# Episode 570, Reward: 27.11, Running Avg (50): 21.95
# update with length 1000
# Episode 580, Reward: 28.91, Running Avg (50): 22.93
# Episode 590, Reward: 8.18, Running Avg (50): 23.98
# Episode 600, Reward: 27.22, Running Avg (50): 23.45
# update with length 1000
# Episode 610, Reward: 27.71, Running Avg (50): 23.29
# Episode 620, Reward: 27.33, Running Avg (50): 23.19
# Episode 630, Reward: 7.71, Running Avg (50): 22.42
# update with length 1000
# Episode 640, Reward: 27.60, Running Avg (50): 22.70
# Episode 650, Reward: 7.42, Running Avg (50): 23.43
# Episode 660, Reward: 27.29, Running Avg (50): 21.20
# update with length 1000
# Episode 670, Reward: 23.36, Running Avg (50): 20.35
# Episode 680, Reward: 28.16, Running Avg (50): 19.66
# Episode 690, Reward: 6.69, Running Avg (50): 18.05
# Episode 700, Reward: 11.49, Running Avg (50): 17.80
# update with length 1000
# Episode 710, Reward: 27.33, Running Avg (50): 20.57
# Episode 720, Reward: 27.09, Running Avg (50): 21.35
# update with length 1000
# Episode 730, Reward: 28.91, Running Avg (50): 22.34
# Episode 740, Reward: 8.53, Running Avg (50): 22.78
# Episode 750, Reward: 28.76, Running Avg (50): 22.63
# Episode 760, Reward: 7.38, Running Avg (50): 20.55
# update with length 1000
# Episode 770, Reward: 27.29, Running Avg (50): 19.63
# Episode 780, Reward: 27.56, Running Avg (50): 18.32
# Episode 790, Reward: 28.60, Running Avg (50): 19.55
# Episode 800, Reward: 28.76, Running Avg (50): 19.85
# update with length 1000
# Episode 810, Reward: 28.73, Running Avg (50): 21.65
# Episode 820, Reward: 10.98, Running Avg (50): 21.59
# update with length 1000
# Episode 830, Reward: 17.47, Running Avg (50): 23.34
# Episode 840, Reward: 8.82, Running Avg (50): 22.83
# Episode 850, Reward: 26.96, Running Avg (50): 23.01
# Episode 860, Reward: 28.24, Running Avg (50): 23.17
# update with length 1000
# Episode 870, Reward: 12.49, Running Avg (50): 23.30
# Episode 880, Reward: 4.91, Running Avg (50): 21.89
# Episode 890, Reward: 28.69, Running Avg (50): 21.36
# update with length 1000
# Episode 900, Reward: 29.02, Running Avg (50): 21.27
# Episode 910, Reward: 28.40, Running Avg (50): 19.72
# Episode 920, Reward: 8.11, Running Avg (50): 18.56
# Episode 930, Reward: 2.93, Running Avg (50): 17.05
# update with length 1000
# Episode 940, Reward: 28.04, Running Avg (50): 18.49
# Episode 950, Reward: 16.64, Running Avg (50): 18.60
# Episode 960, Reward: 3.44, Running Avg (50): 17.32
# Episode 970, Reward: 4.89, Running Avg (50): 18.67
# update with length 1000
# Episode 980, Reward: 28.98, Running Avg (50): 19.93
# Episode 990, Reward: 28.36, Running Avg (50): 19.19
# Episode 1000, Reward: 16.13, Running Avg (50): 19.19
